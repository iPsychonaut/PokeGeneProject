# %%
GIT_CSV = 'https://gist.githubusercontent.com/iPsychonaut/254f8c24b47c4e373664fb75cadf8efc/raw/a76109f6c8e0ae174ce661cf4452e9a04688fba7/pokemon.csv'

FINAL_ORDER_LIST = ['NUMBER',
                    'CODE',
                    'SERIAL',
                    'GENERATION',
                    'REGION',
                    'NAME',
                    'BODY_TYPE', 
                    'EGG_GROUP1',
                    'EGG_GROUP2',
                    'TYPE1',
                    'TYPE2',
                    'ABILITY1',
                    'ABILITY2',
                    'HIDDEN_ABILITY',
                    'MOVES',
                    'GENDER_RATIOS(M:F)',
                    'HP',
                    'ATK',
                    'DEF',
                    'SP_ATK',
                    'SP_DEF',
                    'SPD',
                    'STEPS_TO_HATCH',
                    'LOCATIONS']
BODY_TYPE_LIST = ['Only Head',
                  'Serpentine',
                  'Finned',
                  'Head & Arms',
                  'Head & Base',
                  'Bipedal & Tailed',
                  'Head & Legs',
                  'Quadrapedal',
                  'Single Wings',
                  'Tentacles or Multi-body',
                  'Multi-body',
                  'Bipedal',
                  'Multi-wings',
                  'Insectoid']

GENERATIONS_LIST = ['Unknown',
                    'Kantonian',
                    'Johtonian',
                    'Hoennian',
                    'Sinnohan',
                    'Unovan',
                    'Kalosian',
                    'Alolan',
                    'Galarian/Hisuian']
GALARIAN_FORM_LIST = ['Meowth',
                      'Ponyta',
                      'Rapidash',
                      'Slowpoke',
                      'Slowbro',
                      "Farfetch'd",
                      'Weezing',
                      'Mr. Mime',
                      'Articuno',
                      'Zapdos',
                      'Moltres',
                      'Slowking',
                      'Corsola',
                      'Zigzagoon',
                      'Linoone',
                      'Darumaka',
                      'Darmanitan',
                      'Yamask',
                      'Stunfisk',
                      'Obstagoon']
GALARIAN_DEBUT_LIST = ['Grookey',
                       'Thwackey',
                       'Rillaboom',
                       'Scorbunny',
                       'Raboot',
                       'Cinderace',
                       'Sobble',
                       'Drizzile',
                       'Inteleon',
                       'Skwovet',
                       'Greedent',
                       'Rookidee',
                       'Corvisquire',
                       'Corviknight',
                       'Blipbug',
                       'Dottler',
                       'Orbeetle',
                       'Nickit',
                       'Thievul',
                       'Gossifleur',
                       'Eldegoss',
                       'Wooloo',
                       'Dubwool',
                       'Chewtle',
                       'Drednaw',
                       'Yamper',
                       'Boltund',
                       'Rolycoly',
                       'Carkol',
                       'Coalossal',
                       'Applin',
                       'Flapple',
                       'Appletun',
                       'Silicobra',
                       'Sandaconda',
                       'Cramorant',
                       'Arrokuda',
                       'Barraskewda',
                       'Toxel',
                       'Toxtricity',
                       'Sizzlipede',
                       'Centiskorch',
                       'Clobbopus',
                       'Grapploct',
                       'Sinistea',
                       'Polteageist',
                       'Hatenna',
                       'Hattrem',
                       'Hatterene',
                       'Impidimp',
                       'Morgrem',
                       'Grimmsnarl',
                       'Obstagoon',
                       'Perrserker',
                       'Cursola',
                       "Sirfetch'd",
                       'Mr. Rime',
                       'Runerigus',
                       'Milcery',
                       'Alcremie',
                       'Falinks',
                       'Pincurchin',
                       'Snom',
                       'Frosmoth',
                       'Stonjourner',
                       'Eiscue',
                       'Indeedee M',
                       'Indeedee F',
                       'Morpeko',
                       'Cufant',
                       'Copperajah',
                       'Dracozolt',
                       'Arctozolt',
                       'Dracovish',
                       'Arctovish',
                       'Duraludon',
                       'Dreepy',
                       'Drakloak',
                       'Dragapult',
                       'Zacian',
                       'Zamazenta',
                       'Eternatus',
                       'Kubfu',
                       'Urshifu',
                       'Zarude',
                       'Regieleki',
                       'Regidrago',
                       'Glastrier',
                       'Spectrier',
                       'Calyrex']
HISUIAN_FORM_LIST = ['Decidueye',
                     'Typhlosion',
                     'Samurott',
                     'Qwilfish',
                     'Lilligant',
                     'Sliggoo',
                     'Goodra',
                     'Growlithe',
                     'Arcanine',
                     'Voltorb',
                     'Electrode',
                     'Sneasel',
                     'Avalugg',
                     'Zorua',
                     'Zoroark',
                     'Braviary']
HISUIAN_DEBUT_LIST = ['Wyrdeer',
                      'Kleavor',
                      'Ursaluna',
                      'Basculegion',
                      'Sneasler',
                      'Overqwil',
                      'Enamorus']
MEGA_DICT = {'Venusaur':['Mega Venusaur'],
             'Charizard':['Mega Charizard X','Mega Charizard Y'],
             'Blastoise':['Mega Blastoise'],
             'Beedrill':['Mega Beedrill'],
             'Pidgeot':['Mega Pidgeot'],
             'Alakazam':['Mega Alakazam'],
             'Slowbro':['Mega Slowbro'],
             'Gengar':['Mega Gengar'],
             'Kangaskhan':['Mega Kangaskhan'],
             'Pinsir':['Mega Pinsir'],
             'Gyarados':['Mega Gyarados'],
             'Aerodactyl':['Mega Aerodactyl'],
             'Mewtwo':['Mega Mewtwo X','Mega Mewtwo Y'],
             'Ampharos':['Mega Ampharos'],
             'Steelix':['Mega Steelix'],
             'Scizor':['Mega Scizor'],
             'Heracross':['Mega Heracross'],
             'Houndoom':['Mega Houndoom'],
             'Tyranitar':['Mega Tyranitar'],
             'Sceptile':['Mega Sceptile'],
             'Blaziken':['Mega Blaziken'],
             'Swampert':['Mega Swampert'],
             'Gardevoir':['Mega Gardevoir'],
             'Sableye':['Mega Sableye'],
             'Mawile':['Mega Mawile'],
             'Aggron':['Mega Aggron'],
             'Medicham':['Mega Medicham'],
             'Manectric':['Mega Manectric'],
             'Sharpedo':['Mega Sharpedo'],
             'Camerupt':['Mega Camerupt'],
             'Altaria':['Mega Altaria'],
             'Banette':['Mega Banette'],
             'Absol':['Mega Absol'],
             'Glalie':['Mega Glalie'],
             'Salamence':['Mega Salamence'],
             'Metagross':['Mega Metagross'],
             'Latias':['Mega Latias'],
             'Latios':['Mega Latios'],
             'Rayquaza':['Mega Rayquaza'],
             'Lopunny':['Mega Lopunny'],
             'Garchomp':['Mega Garchomp'],
             'Lucario':['Mega Lucario'],
             'Abomasnow':['Mega Abomasnow'],
             'Gallade':['Mega Gallade'],
             'Audino':['Mega Audino'],
             'Diancie':['Mega Diancie']}
ALT_FORM_DICT = {'Castform':['Normal','Sunny','Rainy','Snowy'],
                 'Kyogre':['Modern','Primal'],
                 'Groudon':['Modern','Primal'],
                 'Deoxys':['Normal','Attack','Defense','Speed'],
                 'Burmy':['Plant','Sandy','Trash'],
                 'Wormadam':['Plant','Sandy','Trash'],
                 'Rotom':['Normal','Heat','Wash','Frost','Fan','Mow'],
                 'Dialga':['Alternate','Origin'],
                 'Palkia':['Alternate','Origin'],
                 'Giratina':['Alternate','Origin'],
                 'Shaymin':['Land','Sky'],
                 'Basculin':['Red-Striped','Blue-Striped','White-Striped'],
                 'Darmanitan':['Standard','Zen'],
                 'Tornadus':['Incarnate','Therian'],
                 'Thundurus':['Incarnate','Therian'],
                 'Landorus':['Incarnate','Therian'],
                 'Enamorus':['Incarnate','Therian'],
                 'Kyurem':['Standard','White','Black'],
                 'Kaldeo':['Ordinary','Resolute'],
                 'Meloetta':['Aria','Pirouette'],
                 'Aegislash':['Shield','Blade'],
                 'Zygarde':['10%','50%','Complete'],
                 'Hoopa':['Confined','Unbound'],
                 'Oricorio':['Baile','Pom-Pom',"Pa'u",'Sensu'],
                 'Lycanroc':['Midday','Midnight','Dusk'],
                 'Wishiwashi':['Solo','School'],
                 'Minior':['Meteor','Core'],
                 'Necrozma':['Standard','Dusk Mane','Dawn Wings','Ultra'],
                 'Toxtricity':['Amped','Low Key'],
                 'Eiscue':['Ice-Face','Noice-Face'],
                 'Zacien':['Hero','Crowned-Sword'],
                 'Zamazenta':['Hero','Crowned-Shield'],
                 'Eternatus':['Standard','Eternamax'],
                 'Urshifu':['Single Strike','Rapid Strike'],
                 'Calyrex':['Standard','Ice Rider','Shadow Rider'],
                 'Pumpkaboo':['Small Size','Average Size','Large Size','Super Size'],
                 'Gourgeist':['Small Size','Average Size','Large Size','Super Size'],
                 'Greninja':['Standard',"Ash's"],
                 'Deerling':['Spring','Summer','Autumn','Winter'],
                 'Sawsbuck':['Spring','Summer','Autumn','Winter'],
                 'Shellos':['West Sea','East Sea'],
                 'Gastrodon':['West Sea','East Sea'],
                 'Cherrim':['Overcast','Sunshine'],
                 'Arceus':['Normal','Fire','Water','Electric','Grass','Ice','Fighting','Poison','Ground','Flying','Psychic','Bug','Rock','Ghost','Dragon','Dark','Steel','Fairy'],
                 'Silvally':['Normal','Fire','Water','Electric','Grass','Ice','Fighting','Poison','Ground','Flying','Psychic','Bug','Rock','Ghost','Dragon','Dark','Steel','Fairy'],
                 'Genesect':['Standard','Shock Drive','Burn Drive','Chill Drive','Douse Drive']}
#NEED TO INCLUDE GMAX TO ALT_FORMS_DICT
ALT_BODY_DICT = {'Mega Slowbro':['Head & Arms'],
                 'Pinsir':['Bipedal'],
                 'Mega Pinsir':['Multi-wings'],
                 'Alternate Giratina':['Tentacles or Multi-body'],
                 'Origin Giratina':['Serpentine'],
                 'Incarnate Tornadus':['Head & Arms'],
                 'Therian Tornadus':['Single Wings'],
                 'Incarnate Thundurus':['Head & Arms'],
                 'Therian Thundurus':['Bipedal & Tailed'],
                 'Incarnate Landorus':['Head & Arms'],
                 'Therian Landorus':['Quadrapedal'],
                 'Incarnate Enamorus':['Head & Arms'],
                 'Therian Enamorus':['Quadrapedal'],
                 '10% Zygarde':['Quadrapedal'],
                 '50% Zygarde':['Serpentine'],
                 'Complete Zygarde':['Bipedal & Tailed'],
                 'Confined Hoopa':['Head & Arms'],
                 'Unbound Hoopa':['Bipedal & Tailed'],
                 'Midday Lycanroc':['Head & Arms'],
                 'Midnight Lycanroc':['Bipedal & Tailed'],
                 'Dusk Lycanroc':['Head & Arms'],
                 'Solo Wishiwashi':['Finned'],
                 'School Wishiwashi':['Multi-body'],
                 'Standard Necrozma':['Head & Arms'],
                 'Dusk Mane Necrozma':['Quadrapedal'],
                 'Dawn Wings Necrozma':['Single Wings'],
                 'Ultra Necrozma':['Multi-wings'],
                 'Standard Eternatus':['Single Wings'],
                 'Eternamax Eternatus':['Serpentine'],
                 'Standard Calyrex':['Bipedal'],
                 'Ice Rider Calyrex':['Quadrapedal'],
                 'Shadow Rider Calyrex':['Quadrapedal']}
# Ordered in bulbapedia, pokemondb, serebii, and database references
NAME_IRREGULARITIES_DICT = {'Nidoran F': ['Nidoran_%E2%99%80','nidoran-f','nidoranf', 'Nidoran M/F'],
                            'Nidoran M': ['Nidoran_%E2%99%82','nidoran-m','nidoranm','Nidoran M/F'],
                            'Mr. Mime': ['Mr._Mime','mr-mime','mr.mime','Mr. Mime'],
                            'Mime Jr.': ['Mime_Jr.','mime-jr','mimejr.','Mime Jr.'],
                            'Mr. Rime': ['Mr._Rime','mr-rime','mr.rime','Mr. Rime'],
                            "Farfetch'd": ["Farfetch'd","farfetchd","farfetch'd","Farfetch'd"],
                            "Sirfetch'd": ["Sirfetch'd","sirfetchd","sirfetch'd","Sirfetch'd"],
                            'Meowstic M': ['Meowstic','meowstic','meowstic','Meowstic M/F'],
                            'Meowstic F': ['Meowstic','meowstic','meowstic','Meowstic M/F'],
                            'Indeedee M': ['Indeedee','indeedee','indeedee','Indeedee M/F'],
                            'Indeedee F': ['Indeedee','indeedee','indeedee','Indeedee M/F'],
                            'Type: Null': ['Type:_Null','type-null','type:null','Type: Null'],
                            'Tapu Koko': ['Tapu_Koko','tapu-koko','tapukoko','Tapu Koko'],
                            'Tapu Lele': ['Tapu_Lele','tapu-lele','tapulele','Tapu Lele'],
                            'Tapu Bulu': ['Tapu_Bulu','tapu-bulu','tapubulu','Tapu Bulu'],
                            'Tapu Fini': ['Tapu_Fini','tapu-fini','tapufini','Tapu Fini']}
